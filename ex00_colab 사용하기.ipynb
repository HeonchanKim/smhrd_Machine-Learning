# %%
print("hello world")
# Out:
# hello world

# %%
a,b = 1,3

# %%
print(a)
# Out:
# 1

# %%
input_data = input('값을 입력해주세요 : ')
print(input_data)
# Out:
# 값을 입력해주세요 : 10
# 10

# %% [markdown]
# # 제목

# %% [markdown]
# - 사과
# - 바나나
# - 포도

# %% [markdown]
# ![1234.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #제목2
